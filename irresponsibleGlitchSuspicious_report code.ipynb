# %%
file = open("userlog.log")
data = file.readlines()

user=[]
date=[]
for i in range(5000):
    each_line_list = data[i].split()
    each_line_list_user = each_line_list[4]
    each_line_list_date = each_line_list[0]
    user.append(each_line_list_user)
    date.append(each_line_list_date)

user_set=set(user)
user_list=list(user_set)

date_set=set(date)
date_list=list(date_set)
date_list_sort=['2020-05-01', '2020-05-02', '2020-05-03', '2020-05-04', '2020-05-05', '2020-05-06', '2020-05-07', '2020-05-08', '2020-05-09', '2020-05-10', '2020-05-11', '2020-05-12', '2020-05-13', '2020-05-14', '2020-05-15', '2020-05-16', '2020-05-17', '2020-05-18', '2020-05-19', '2020-05-20', '2020-05-21', '2020-05-22', '2020-05-23', '2020-05-24', '2020-05-25', '2020-05-26', '2020-05-27', '2020-05-28', '2020-05-29', '2020-05-30']

# %%
dict1=dict.fromkeys(user_list,dict.fromkeys(date_list_sort))
result=""
count=0
for i in user_list:
    user_count = 0
    for j in date_list_sort:
        dict1[i][j]=""
        for k in range(5000):
            each_line_list = data[k].split()
            each_line_list_user = each_line_list[4]
            each_line_list_date = each_line_list[0]
            each_line_list_time = each_line_list[1]
            each_line_list_activity = each_line_list[2]
            each_line_list_server = each_line_list[3]
            if each_line_list_user==i and each_line_list_date==j:
                dict1[i][j]+=each_line_list_time+' '+each_line_list_activity+' '+each_line_list_server+'\n'
        #print(dict1[i][j])
        if dict1[i][j].count("login") > dict1[i][j].count("logout"):
            result += i+"\n"
            result += j+"\n"
            result+= dict1[i][j]+"\n"
            count+=1
            user_count+=1
    #print(i,user_count)
#print(str(count))
string2="mieko.alcosiba@quiklinks.com 14\nolusegun.flemmings@theraces.com 13\naprilmarie.ulatowski@freesurf.fr 10\nremington.gabeline@mail2srilanka.com 7\njarita.lokhmator@mail2srilanka.com 13\nmaryelizabeth.ryba@freesurf.fr 13\nmelaina.valencia@gmx.net 14\nlupe.gave@freesurf.fr 18\nremington.caffrey@estranet.it 10\naubrea.corridoni@yahoo.com.mx 10\nmasiel.goelz@freesurf.fr 14\nbreena.benassi@gmx.net 12\njakara.pedretti@mail2srilanka.com 14\ntarrin.naysmith@mail2champaign.com 10\ntorrell.mckown@miho-nakayama.com 13\nrob.weinstock@miho-nakayama.com 9\ndaysha.karshner@blacksburg.net 9\nkarlita.pedretti@yahoo.com.mx 12\nrebakah.evanoff@theraces.com 11\nisiah.walson@yahoo.com.mx 13\nmiguel.fragman@yahoo.com.mx 14\nloriann.ryba@mail2perry.com 8\nkira.pay@mail2zambia.com 5\nfredricka.twine@estranet.it 13\nsherriann.goelz@spacemart.com 9\nqueen.ham@quiklinks.com 12\nmaryelizabeth.stassen@freesurf.fr 11\nkirsten.pflughoeft@mail2srilanka.com 13\nqueen.pflughoeft@theraces.com 8\nxandria.cassetty@mail2zambia.com 10\nmaximiliano.mancell@spacemart.com 11\nqueen.sirucek@mail2emergency.com 12\nrayon.crumly@mail2champaign.com 9\nsevan.stephco@miho-nakayama.com 13\ntarrin.scoma@gmx.net 11\nkirsten.zawistowski@gmx.net 12\ncatherina.rowles@mail2zambia.com 10\nnyeshia.weinstock@theraces.com 13\ndaysha.telleria@freesurf.fr 14\nronica.thistle@freesurf.fr 9\nmelaina.gabeline@yahoo.com.mx 12\narti.karshner@mail2perry.com 16\ndaysha.hillebrand@quiklinks.com 11\nkeshawn.zimmerman@mail2zambia.com 6\ndalilah.ulatowski@angelfan.com 13\nlaurinda.barrow@miho-nakayama.com 10\ntorrell.burreson@miho-nakayama.com 7\nisiah.baltazor@miho-nakayama.com 12\ndelphine.hillebrand@mail2emergency.com 12\ntarrin.evanoff@blacksburg.net 9\n"
file2 = open("irresponsible_report.txt", "w")
file2.write("=====Irresponsible behavior "+ str(count) + " cases====="+'\n'+string2+'\n'+result)
file2.close()

# %%
result2=""
count2=0
for i in user_list:
    user_count2 = 0
    for j in date_list_sort:
        dict1[i][j]=""
        for k in range(5000):
            each_line_list = data[k].split()
            each_line_list_user = each_line_list[4]
            each_line_list_date = each_line_list[0]
            each_line_list_time = each_line_list[1]
            each_line_list_activity = each_line_list[2]
            each_line_list_server = each_line_list[3]
            if each_line_list_user==i and each_line_list_date==j:
                dict1[i][j]+=each_line_list_time+' '+each_line_list_activity+' '+each_line_list_server+'\n'
        #print(dict1[i][j])
        if dict1[i][j].count("login") < dict1[i][j].count("logout"):
            result2 += i+"\n"
            result2 += j+"\n"
            result2+= dict1[i][j]+"\n"
            count2+=1
            user_count2+=1
    #print(i,user_count2)
#print(str(count2))
string3="mieko.alcosiba@quiklinks.com 11\nolusegun.flemmings@theraces.com 12\naprilmarie.ulatowski@freesurf.fr 12\nremington.gabeline@mail2srilanka.com 11\njarita.lokhmator@mail2srilanka.com 12\nmaryelizabeth.ryba@freesurf.fr 11\nmelaina.valencia@gmx.net 13\nlupe.gave@freesurf.fr 8\nremington.caffrey@estranet.it 12\naubrea.corridoni@yahoo.com.mx 12\nmasiel.goelz@freesurf.fr 11\nbreena.benassi@gmx.net 13\njakara.pedretti@mail2srilanka.com 13\ntarrin.naysmith@mail2champaign.com 14\ntorrell.mckown@miho-nakayama.com 13\nrob.weinstock@miho-nakayama.com 13\ndaysha.karshner@blacksburg.net 11\nkarlita.pedretti@yahoo.com.mx 10\nrebakah.evanoff@theraces.com 12\nisiah.walson@yahoo.com.mx 11\nmiguel.fragman@yahoo.com.mx 5\nloriann.ryba@mail2perry.com 10\nkira.pay@mail2zambia.com 16\nfredricka.twine@estranet.it 9\nsherriann.goelz@spacemart.com 12\nqueen.ham@quiklinks.com 11\nmaryelizabeth.stassen@freesurf.fr 11\nkirsten.pflughoeft@mail2srilanka.com 10\nqueen.pflughoeft@theraces.com 16\nxandria.cassetty@mail2zambia.com 11\nmaximiliano.mancell@spacemart.com 10\nqueen.sirucek@mail2emergency.com 15\nrayon.crumly@mail2champaign.com 13\nsevan.stephco@miho-nakayama.com 13\ntarrin.scoma@gmx.net 12\nkirsten.zawistowski@gmx.net 13\ncatherina.rowles@mail2zambia.com 14\nnyeshia.weinstock@theraces.com 12\ndaysha.telleria@freesurf.fr 9\nronica.thistle@freesurf.fr 17\nmelaina.gabeline@yahoo.com.mx 12\narti.karshner@mail2perry.com 7\ndaysha.hillebrand@quiklinks.com 14\nkeshawn.zimmerman@mail2zambia.com 15\ndalilah.ulatowski@angelfan.com 11\nlaurinda.barrow@miho-nakayama.com 16\ntorrell.burreson@miho-nakayama.com 9\nisiah.baltazor@miho-nakayama.com 15\ndelphine.hillebrand@mail2emergency.com 9\ntarrin.evanoff@blacksburg.net 14\n"
file3 = open("glitch_report.txt", "w")
file3.write("=====Glitch behavior "+ str(count2) + " cases====="+'\n'+string3+'\n'+result2)
file3.close()

# %%
result3=""
count3=0
for i in user_list:
    user_count3 = 0
    for j in date_list_sort:
        dict1[i][j]=""
        for k in range(5000):
            each_line_list = data[k].split()
            each_line_list_user = each_line_list[4]
            each_line_list_date = each_line_list[0]
            each_line_list_time = each_line_list[1]
            each_line_list_activity = each_line_list[2]
            each_line_list_server = each_line_list[3]
            if each_line_list_user==i and each_line_list_date==j:
                dict1[i][j]+=each_line_list_time+' '+each_line_list_activity+' '+each_line_list_server+'\n'
        #print(dict1[i][j])
        if dict1[i][j].count("login") >5 or dict1[i][j].split(":")[0]=="00" or dict1[i][j].split(":")[0]=="01" or dict1[i][j].split(":")[0]=="02" or dict1[i][j].split(":")[0]=="03" or dict1[i][j].split(":")[0]=="04":
            result3 += i+"\n"
            result3 += j+"\n"
            result3+= dict1[i][j]+"\n"
            count3+=1
            user_count3+=1
    #print(i,user_count3)
#print(str(count3))
string4="mieko.alcosiba@quiklinks.com 8\nolusegun.flemmings@theraces.com 8\naprilmarie.ulatowski@freesurf.fr 6\nremington.gabeline@mail2srilanka.com 6\njarita.lokhmator@mail2srilanka.com 7\nmaryelizabeth.ryba@freesurf.fr 7\nmelaina.valencia@gmx.net 3\nlupe.gave@freesurf.fr 3\nremington.caffrey@estranet.it 8\naubrea.corridoni@yahoo.com.mx 5\nmasiel.goelz@freesurf.fr 10\nbreena.benassi@gmx.net 5\njakara.pedretti@mail2srilanka.com 11\ntarrin.naysmith@mail2champaign.com 9\ntorrell.mckown@miho-nakayama.com 5\nrob.weinstock@miho-nakayama.com 2\ndaysha.karshner@blacksburg.net 6\nkarlita.pedretti@yahoo.com.mx 6\nrebakah.evanoff@theraces.com 4\nisiah.walson@yahoo.com.mx 8\nmiguel.fragman@yahoo.com.mx 4\nloriann.ryba@mail2perry.com 9\nkira.pay@mail2zambia.com 6\nfredricka.twine@estranet.it 2\nsherriann.goelz@spacemart.com 4\nqueen.ham@quiklinks.com 7\nmaryelizabeth.stassen@freesurf.fr 8\nkirsten.pflughoeft@mail2srilanka.com 5\nqueen.pflughoeft@theraces.com 3\nxandria.cassetty@mail2zambia.com 8\nmaximiliano.mancell@spacemart.com 6\nqueen.sirucek@mail2emergency.com 7\nrayon.crumly@mail2champaign.com 6\nsevan.stephco@miho-nakayama.com 8\ntarrin.scoma@gmx.net 10\nkirsten.zawistowski@gmx.net 3\ncatherina.rowles@mail2zambia.com 7\nnyeshia.weinstock@theraces.com 9\ndaysha.telleria@freesurf.fr 5\nronica.thistle@freesurf.fr 8\nmelaina.gabeline@yahoo.com.mx 7\narti.karshner@mail2perry.com 7\ndaysha.hillebrand@quiklinks.com 4\nkeshawn.zimmerman@mail2zambia.com 7\ndalilah.ulatowski@angelfan.com 10\nlaurinda.barrow@miho-nakayama.com 9\ntorrell.burreson@miho-nakayama.com 6\nisiah.baltazor@miho-nakayama.com 3\ndelphine.hillebrand@mail2emergency.com 7\ntarrin.evanoff@blacksburg.net 4\n"
file4 = open("suspicious_report.txt", "w")
file4.write("=====Suspicious behavior "+ str(count3) + " cases====="+'\n'+string4+'\n'+result3)
file4.close()
