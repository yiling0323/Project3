# %%
file = open("userlog.log")
data = file.readlines()

user=[]
date=[]
for i in range(5000):
    each_line_list = data[i].split()
    each_line_list_user = each_line_list[4]
    each_line_list_date = each_line_list[0]
    user.append(each_line_list_user)
    date.append(each_line_list_date)

user_set=set(user)
user_list=list(user_set)

date_set=set(date)
date_list=list(date_set)
#print(data_list)
date_list_sort=['2020-05-01', '2020-05-02', '2020-05-03', '2020-05-04', '2020-05-05', '2020-05-06', '2020-05-07', '2020-05-08', '2020-05-09', '2020-05-10', '2020-05-11', '2020-05-12', '2020-05-13', '2020-05-14', '2020-05-15', '2020-05-16', '2020-05-17', '2020-05-18', '2020-05-19', '2020-05-20', '2020-05-21', '2020-05-22', '2020-05-23', '2020-05-24', '2020-05-25', '2020-05-26', '2020-05-27', '2020-05-28', '2020-05-29', '2020-05-30']

# %%
dict1=dict.fromkeys(user_list,dict.fromkeys(date_list_sort))
for i in user_list:
    print(i)
    for j in date_list_sort:
        print(j)
        dict1[i][j]=""
        for k in range(5000):
            each_line_list = data[k].split()
            each_line_list_user = each_line_list[4]
            each_line_list_date = each_line_list[0]
            each_line_list_time = each_line_list[1]
            each_line_list_activity = each_line_list[2]
            each_line_list_server = each_line_list[3]
            
            if each_line_list_user==i and each_line_list_date==j:
                print(each_line_list_time+' '+each_line_list_activity+' '+each_line_list_server+'\n')
# Out:
# loriann.ryba@mail2perry.com
# 2020-05-01
# 23:03:02 login mailserver.local
#
# 13:43:49 logout mailserver.local
#
# 2020-05-02
# 10:47:48 logout mailserver.local
#
# 02:42:43 logout myworkstation.local
#
# 2020-05-03
# 03:14:15 logout myworkstation.local
#
# 14:42:58 logout webserver.local
#
# 13:02:33 login myworkstation.local
#
# 2020-05-04
# 20:23:59 logout mailserver.local
#
# 16:59:28 login webserver.local
#
# 2020-05-05
# 00:53:49 logout webserver.local
#
# 02:30:05 login myworkstation.local
#
# 2020-05-06
# 09:13:11 login webserver.local
#
# 04:24:07 logout mailserver.local
#
# 2020-05-07
# 04:18:01 login mailserver.local
#
# 11:26:20 logout myworkstation.local
#
# 17:54:56 logout mailserver.local
#
# 15:25:31 login webserver.local
#
# 10:28:59 logout mailserver.local
#
# 22:40:27 login myworkstation.local
#
# 2020-05-08
# 2020-05-09
# 16:30:14 logout webserver.local
#
# 00:24:08 login webserver.local
#
# 2020-05-10
# 14:35:47 logout mailserver.local
#
# 22:11:33 login myworkstation.local
#
# 22:53:02 logout webserver.local
#
# 19:34:41 logout myworkstation.local
#
# 2020-05-11
# 22:59:21 login webserver.local
#
# 11:17:23 logout myworkstation.local
#
# 10:25:47 login webserver.local
#
# 2020-05-12
# 21:40:26 login webserver.local
#
# 20:05:04 logout webserver.local
#
# 21:44:22 logout myworkstation.local
#
# 21:15:29 login myworkstation.local
#
# 2020-05-13
# 23:23:46 login myworkstation.local
#
# 10:55:12 login mailserver.local
#
# 08:31:52 login webserver.local
#
# 06:29:50 login myworkstation.local
#
# 09:12:40 logout mailserver.local
#
# 08:51:23 login myworkstation.local
#
# 2020-05-14
# 02:00:25 logout mailserver.local
#
# 22:34:43 logout webserver.local
#
# 08:15:33 logout myworkstation.local
#
# 02:55:46 login myworkstation.local
#
# 2020-05-15
# 10:07:29 logout webserver.local
#
# 16:45:58 login myworkstation.local
#
# 07:56:00 login webserver.local
#
# 2020-05-16
# 2020-05-17
# 04:33:43 login webserver.local
#
# 2020-05-18
# 20:11:26 login myworkstation.local
#
# 2020-05-19
# 00:27:00 login myworkstation.local
#
# 03:14:58 logout myworkstation.local
#
# 19:28:44 login webserver.local
#
# 21:27:54 logout webserver.local
#
# 20:46:43 logout myworkstation.local
#
# 06:20:54 login myworkstation.local
#
# 2020-05-20
# 00:51:06 logout webserver.local
#
# 2020-05-21
# 00:19:51 logout myworkstation.local
#
# 14:17:45 logout mailserver.local
#
# 08:10:15 login webserver.local
#
# 2020-05-22
# 16:45:52 login mailserver.local
#
# 15:43:46 logout mailserver.local
#
# 03:57:22 login mailserver.local
#
# 2020-05-23
# 21:38:58 logout webserver.local
#
# 2020-05-24
# 16:41:36 logout webserver.local
#
# 18:55:02 logout myworkstation.local
#
# 18:06:18 login webserver.local
#
# 10:54:07 login myworkstation.local
#
# 2020-05-25
# 23:44:09 login mailserver.local
#
# 07:07:40 logout myworkstation.local
#
# 22:32:14 login myworkstation.local
#
# 22:59:12 login mailserver.local
#
# 2020-05-26
# 17:13:01 login webserver.local
#
# 18:54:44 logout webserver.local
#
# 23:16:50 login myworkstation.local
#
# 2020-05-27
# 09:49:28 logout webserver.local
#
# 09:37:21 login myworkstation.local
#
# 22:04:27 login webserver.local
#
# 04:49:27 logout mailserver.local
#
# 2020-05-28
# 21:16:13 logout webserver.local
#
# 08:21:49 logout myworkstation.local
#
# 2020-05-29
# 00:27:32 logout mailserver.local
#
# 00:47:28 logout myworkstation.local
#
# 16:35:06 logout webserver.local
#
# 00:00:04 logout mailserver.local
#
# 11:15:43 logout myworkstation.local
#
# 02:02:38 logout myworkstation.local
#
# 13:04:36 logout myworkstation.local
#
# 17:03:21 logout myworkstation.local
#
# 2020-05-30
# 21:24:44 login mailserver.local
#
# 06:09:09 logout mailserver.local
#
# 15:56:36 logout webserver.local
#
# delphine.hillebrand@mail2emergency.com
# 2020-05-01
# 08:52:35 login mailserver.local
#
# 13:22:52 logout webserver.local
#
# 2020-05-02
# 14:03:43 login mailserver.local
#
# 17:23:31 login webserver.local
#
# 23:13:50 login mailserver.local
#
# 2020-05-03
# 20:10:56 login webserver.local
#
# 03:11:02 logout mailserver.local
#
# 2020-05-04
# 16:51:33 login webserver.local
#
# 11:50:37 logout webserver.local
#
# 11:31:50 login myworkstation.local
#
# 10:04:23 logout mailserver.local
#
# 2020-05-05
# 21:37:32 logout webserver.local
#
# 17:29:08 logout webserver.local
#
# 2020-05-06
# 02:36:34 logout mailserver.local
#
# 2020-05-07
# 22:00:10 login myworkstation.local
#
# 01:41:36 login mailserver.local
#
# 05:15:22 login webserver.local
#
# 16:57:35 logout myworkstation.local
#
# 14:25:49 login webserver.local
#
# 06:41:40 logout myworkstation.local
#
# 2020-05-08
# 13:36:14 logout mailserver.local
#
# 04:33:25 login mailserver.local
#
# 14:09:37 login webserver.local
#
# 03:40:46 logout webserver.local
#
# 2020-05-09
# 16:59:26 logout myworkstation.local
#
# 20:22:33 logout myworkstation.local
#
# 17:16:38 login webserver.local
#
# 16:21:34 login mailserver.local
#
# 2020-05-10
# 05:13:34 logout mailserver.local
#
# 22:49:59 logout mailserver.local
#
# 2020-05-11
# 00:36:32 logout myworkstation.local
#
# 01:15:43 logout myworkstation.local
#
# 10:53:10 login myworkstation.local
#
# 10:24:49 login webserver.local
#
# 07:05:59 logout mailserver.local
#
# 11:20:39 login myworkstation.local
#
# 01:34:50 logout myworkstation.local
#
# 2020-05-12
# 13:43:37 login myworkstation.local
#
# 21:44:56 logout mailserver.local
#
# 02:25:56 logout webserver.local
#
# 05:44:44 logout mailserver.local
#
# 2020-05-13
# 00:20:06 login mailserver.local
#
# 09:37:31 login webserver.local
#
# 01:03:21 login mailserver.local
#
# 15:08:02 logout myworkstation.local
#
# 2020-05-14
# 21:25:52 logout webserver.local
#
# 06:05:06 logout mailserver.local
#
# 09:39:25 logout mailserver.local
#
# 2020-05-15
# 00:27:26 login mailserver.local
#
# 2020-05-16
# 16:52:56 logout webserver.local
#
# 13:51:07 login mailserver.local
#
# 14:19:05 logout webserver.local
#
# 01:43:09 login webserver.local
#
# 16:31:56 login myworkstation.local
#
# 2020-05-17
# 11:14:15 logout myworkstation.local
#
# 11:03:01 logout mailserver.local
#
# 21:39:24 logout myworkstation.local
#
# 03:30:33 logout webserver.local
#
# 2020-05-18
# 14:04:30 logout webserver.local
#
# 08:25:58 login webserver.local
#
# 07:26:19 logout webserver.local
#
# 08:24:18 login myworkstation.local
#
# 2020-05-19
# 01:39:36 logout myworkstation.local
#
# 2020-05-20
# 23:52:49 login mailserver.local
#
# 09:41:24 logout webserver.local
#
# 19:44:00 logout webserver.local
#
# 18:22:34 login myworkstation.local
#
# 2020-05-21
# 15:53:35 login webserver.local
#
# 14:13:28 login mailserver.local
#
# 11:23:58 logout webserver.local
#
# 14:54:52 login mailserver.local
#
# 23:59:28 login webserver.local
#
# 2020-05-22
# 15:50:19 logout myworkstation.local
#
# 04:10:56 login mailserver.local
#
# 00:55:11 login mailserver.local
#
# 01:18:07 login mailserver.local
#
# 01:50:54 logout myworkstation.local
#
# 2020-05-23
# 2020-05-24
# 19:12:21 login webserver.local
#
# 2020-05-25
# 19:55:20 logout webserver.local
#
# 21:23:57 login webserver.local
#
# 08:52:17 logout myworkstation.local
#
# 02:11:40 logout mailserver.local
#
# 2020-05-26
# 08:59:28 login myworkstation.local
#
# 15:41:59 login mailserver.local
#
# 23:10:56 login mailserver.local
#
# 01:21:12 logout myworkstation.local
#
# 2020-05-27
# 01:46:25 login webserver.local
#
# 2020-05-28
# 00:13:11 logout webserver.local
#
# 15:49:54 login webserver.local
#
# 2020-05-29
# 08:34:15 logout webserver.local
#
# 04:28:02 login webserver.local
#
# 08:11:20 login mailserver.local
#
# 2020-05-30
# 07:22:33 login myworkstation.local
#
# 04:04:00 logout webserver.local
#
# 15:24:47 login webserver.local
#
# 06:09:39 logout webserver.local
#
# 15:46:35 login myworkstation.local
#
# rebakah.evanoff@theraces.com
# 2020-05-01
# 08:17:07 login myworkstation.local
#
# 21:53:50 logout mailserver.local
#
# 17:51:21 login mailserver.local
#
# 21:11:54 login myworkstation.local
#
# 2020-05-02
# 07:02:55 login myworkstation.local
#
# 16:28:43 login mailserver.local
#
# 2020-05-03
# 16:38:22 login mailserver.local
#
# 09:26:23 logout mailserver.local
#
# 17:21:45 login mailserver.local
#
# 19:54:53 logout mailserver.local
#
# 2020-05-04
# 09:19:17 login mailserver.local
#
# 04:50:38 login webserver.local
#
# 2020-05-05
# 22:51:14 login myworkstation.local
#
# 21:24:41 logout mailserver.local
#
# 18:08:16 login myworkstation.local
#
# 13:44:19 logout mailserver.local
#
# 08:07:18 logout mailserver.local
#
# 02:37:10 login webserver.local
#
# 21:30:54 login webserver.local
#
# 17:50:19 logout myworkstation.local
#
# 2020-05-06
# 05:45:40 logout mailserver.local
#
# 01:39:03 logout mailserver.local
#
# 2020-05-07
# 05:45:30 login mailserver.local
#
# 22:21:24 logout mailserver.local
#
# 2020-05-08
# 07:44:52 login myworkstation.local
#
# 06:37:52 login webserver.local
#
# 2020-05-09
# 12:11:03 logout webserver.local
#
# 16:31:55 login mailserver.local
#
# 02:47:55 logout myworkstation.local
#
# 21:13:47 logout webserver.local
#
# 09:54:47 logout mailserver.local
#
# 2020-05-10
# 12:38:26 logout myworkstation.local
#
# 07:30:17 login mailserver.local
#
# 17:07:47 logout webserver.local
#
# 2020-05-11
# 05:17:31 login myworkstation.local
#
# 02:59:11 logout myworkstation.local
#
# 09:31:10 logout myworkstation.local
#
# 2020-05-12
# 09:50:55 logout myworkstation.local
#
# 12:04:10 login myworkstation.local
#
# 15:53:18 logout myworkstation.local
#
# 02:13:30 logout webserver.local
#
# 09:38:10 logout myworkstation.local
#
# 2020-05-13
# 07:12:14 login mailserver.local
#
# 09:08:26 login mailserver.local
#
# 2020-05-14
# 09:34:06 logout mailserver.local
#
# 15:38:45 logout myworkstation.local
#
# 10:03:37 login webserver.local
#
# 12:00:26 logout myworkstation.local
#
# 18:39:12 logout mailserver.local
#
# 2020-05-15
# 15:24:46 logout myworkstation.local
#
# 08:26:37 login myworkstation.local
#
# 2020-05-16
# 09:14:24 login mailserver.local
#
# 00:01:23 login mailserver.local
#
# 22:01:44 login mailserver.local
#
# 03:19:41 logout myworkstation.local
#
# 04:00:16 login mailserver.local
#
# 22:57:44 logout myworkstation.local
#
# 05:29:47 logout webserver.local
#
# 2020-05-17
# 13:20:23 login myworkstation.local
#
# 08:17:02 login mailserver.local
#
# 08:50:34 login myworkstation.local
#
# 00:58:57 login webserver.local
#
# 03:22:44 login webserver.local
#
# 2020-05-18
# 04:00:32 login mailserver.local
#
# 11:03:15 logout myworkstation.local
#
# 2020-05-19
# 10:01:39 logout myworkstation.local
#
# 18:38:20 logout myworkstation.local
#
# 08:31:09 logout webserver.local
#
# 20:53:17 login mailserver.local
#
# 2020-05-20
# 05:14:21 login webserver.local
#
# 04:57:21 login webserver.local
#
# 07:12:20 logout mailserver.local
#
# 2020-05-21
# 12:41:50 logout mailserver.local
#
# 05:48:55 login myworkstation.local
#
# 11:50:27 login myworkstation.local
#
# 07:07:44 logout webserver.local
#
# 07:45:37 login mailserver.local
#
# 02:56:00 login webserver.local
#
# 2020-05-22
# 02:20:37 logout webserver.local
#
# 08:46:49 login myworkstation.local
#
# 12:19:30 logout myworkstation.local
#
# 16:01:48 logout mailserver.local
#
# 2020-05-23
# 07:09:35 logout myworkstation.local
#
# 17:36:48 login myworkstation.local
#
# 06:00:45 logout webserver.local
#
# 18:18:41 logout mailserver.local
#
# 10:14:06 login mailserver.local
#
# 2020-05-24
# 03:57:04 login mailserver.local
#
# 10:26:08 logout myworkstation.local
#
# 10:42:31 login mailserver.local
#
# 19:46:29 logout myworkstation.local
#
# 2020-05-25
# 22:21:42 login mailserver.local
#
# 20:16:51 logout mailserver.local
#
# 01:53:28 logout webserver.local
#
# 00:50:55 logout myworkstation.local
#
# 2020-05-26
# 01:46:12 login myworkstation.local
#
# 11:16:50 login myworkstation.local
#
# 06:04:29 login myworkstation.local
#
# 21:55:59 login webserver.local
#
# 2020-05-27
# 09:31:32 login myworkstation.local
#
# 2020-05-28
# 05:41:38 login myworkstation.local
#
# 07:08:53 login webserver.local
#
# 16:55:19 logout mailserver.local
#
# 06:12:47 logout mailserver.local
#
# 2020-05-29
# 19:33:36 login mailserver.local
#
# 15:59:11 logout myworkstation.local
#
# 00:57:34 logout myworkstation.local
#
# 2020-05-30
# 13:29:28 logout myworkstation.local
#
# maryelizabeth.ryba@freesurf.fr
# 2020-05-01
# 08:40:27 logout mailserver.local
#
# 01:45:55 logout webserver.local
#
# 2020-05-02
# 22:45:44 login mailserver.local
#
# 11:40:43 logout myworkstation.local
#
# 05:46:43 logout myworkstation.local
#
# 15:17:01 login myworkstation.local
#
# 22:19:55 login myworkstation.local
#
# 06:23:52 login mailserver.local
#
# 21:41:26 login mailserver.local
#
# 08:48:00 logout webserver.local
#
# 2020-05-03
# 02:29:25 login myworkstation.local
#
# 08:17:13 login myworkstation.local
#
# 08:40:35 login mailserver.local
#
# 2020-05-04
# 14:07:01 logout webserver.local
#
# 2020-05-05
# 07:58:36 logout myworkstation.local
#
# 15:57:45 logout webserver.local
#
# 2020-05-06
# 10:00:50 login webserver.local
#
# 03:47:25 login myworkstation.local
#
# 13:37:08 login myworkstation.local
#
# 03:24:17 login mailserver.local
#
# 2020-05-07
# 18:41:39 login myworkstation.local
#
# 15:27:11 login webserver.local
#
# 2020-05-08
# 09:00:57 logout mailserver.local
#
# 22:11:20 login webserver.local
#
# 14:16:46 login myworkstation.local
#
# 10:21:55 logout webserver.local
#
# 10:33:42 logout mailserver.local
#
# 00:39:10 logout mailserver.local
#
# 05:13:17 logout myworkstation.local
#
# 2020-05-09
# 23:58:18 login webserver.local
#
# 06:07:41 logout mailserver.local
#
# 07:00:35 login myworkstation.local
#
# 2020-05-10
# 07:59:53 login myworkstation.local
#
# 09:47:21 logout webserver.local
#
# 2020-05-11
# 14:33:12 logout mailserver.local
#
# 18:54:36 logout myworkstation.local
#
# 06:37:11 login webserver.local
#
# 2020-05-12
# 08:47:49 login myworkstation.local
#
# 17:28:29 login mailserver.local
#
# 2020-05-13
# 00:38:31 login webserver.local
#
# 09:33:02 logout mailserver.local
#
# 06:37:20 login mailserver.local
#
# 01:21:40 login webserver.local
#
# 2020-05-14
# 03:59:12 logout mailserver.local
#
# 09:58:39 login webserver.local
#
# 19:03:55 login mailserver.local
#
# 03:44:32 logout webserver.local
#
# 2020-05-15
# 11:58:17 logout webserver.local
#
# 07:52:12 logout mailserver.local
#
# 01:09:55 logout myworkstation.local
#
# 22:44:54 logout myworkstation.local
#
# 12:19:25 logout myworkstation.local
#
# 04:56:11 logout mailserver.local
#
# 17:30:56 logout mailserver.local
#
# 2020-05-16
# 09:16:29 login mailserver.local
#
# 01:24:16 login myworkstation.local
#
# 06:09:51 login webserver.local
#
# 2020-05-17
# 14:45:14 login myworkstation.local
#
# 01:51:43 logout mailserver.local
#
# 21:54:10 logout myworkstation.local
#
# 08:55:29 logout webserver.local
#
# 2020-05-18
# 03:01:38 login webserver.local
#
# 20:27:29 login webserver.local
#
# 08:25:51 logout mailserver.local
#
# 2020-05-19
# 16:21:27 logout webserver.local
#
# 00:55:28 logout webserver.local
#
# 06:30:51 login mailserver.local
#
# 19:22:43 logout webserver.local
#
# 00:34:32 login myworkstation.local
#
# 01:30:33 logout mailserver.local
#
# 2020-05-20
# 05:09:41 logout webserver.local
#
# 2020-05-21
# 07:33:09 logout mailserver.local
#
# 13:09:11 login mailserver.local
#
# 2020-05-22
# 10:02:37 logout webserver.local
#
# 22:20:56 login myworkstation.local
#
# 2020-05-23
# 04:21:34 logout webserver.local
#
# 09:39:04 logout mailserver.local
#
# 08:30:15 login webserver.local
#
# 11:28:37 login mailserver.local
#
# 2020-05-24
# 05:00:41 login myworkstation.local
#
# 00:29:12 login myworkstation.local
#
# 07:16:45 logout mailserver.local
#
# 17:10:40 login mailserver.local
#
# 21:18:46 logout mailserver.local
#
# 02:30:25 login myworkstation.local
#
# 2020-05-25
# 00:14:56 logout webserver.local
#
# 2020-05-26
# 23:40:11 logout webserver.local
#
# 14:43:28 login webserver.local
#
# 20:45:51 login mailserver.local
#
# 00:00:04 logout mailserver.local
#
# 2020-05-27
# 01:54:32 login webserver.local
#
# 19:47:09 logout webserver.local
#
# 00:15:44 login webserver.local
#
# 22:09:41 login myworkstation.local
#
# 06:06:51 logout mailserver.local
#
# 2020-05-28
# 20:56:03 login mailserver.local
#
# 22:51:27 login webserver.local
#
# 22:07:36 logout mailserver.local
#
# 22:06:38 logout mailserver.local
#
# 20:14:41 login mailserver.local
#
# 16:22:48 login webserver.local
#
# 2020-05-29
# 20:54:51 login myworkstation.local
#
# 20:44:33 login myworkstation.local
#
# 01:48:54 logout myworkstation.local
#
# 2020-05-30
# 15:00:49 logout myworkstation.local
#
# 19:08:47 logout webserver.local
#
# 04:41:02 logout mailserver.local
#
# 09:47:24 logout mailserver.local
#
# 18:26:44 logout mailserver.local
#
# 02:47:09 logout webserver.local
#
# 17:34:18 logout mailserver.local
#
# tarrin.evanoff@blacksburg.net
# 2020-05-01
# 18:11:51 logout myworkstation.local
#
# 10:09:52 logout mailserver.local
#
# 09:19:56 login myworkstation.local
#
# 14:42:54 logout myworkstation.local
#
# 2020-05-02
# 00:50:58 logout myworkstation.local
#
# 04:14:25 logout webserver.local
#
# 03:27:51 login myworkstation.local
#
# 2020-05-03
# 17:46:42 logout webserver.local
#
# 03:52:47 login myworkstation.local
#
# 13:18:31 logout webserver.local
#
# 08:56:59 login myworkstation.local
#
# 02:22:18 logout webserver.local
#
# 2020-05-04
# 22:19:37 login webserver.local
#
# 00:01:25 logout webserver.local
#
# 20:51:13 logout webserver.local
#
# 15:30:01 login mailserver.local
#
# 2020-05-05
# 2020-05-06
# 2020-05-07
# 16:56:18 login mailserver.local
#
# 23:40:24 login myworkstation.local
#
# 13:32:01 login webserver.local
#
# 2020-05-08
# 09:22:27 login webserver.local
#
# 03:44:59 login webserver.local
#
# 20:08:53 login webserver.local
#
# 2020-05-09
# 15:06:54 logout webserver.local
#
# 18:03:08 login webserver.local
#
# 13:22:04 login webserver.local
#
# 2020-05-10
# 22:58:01 logout webserver.local
#
# 23:42:06 logout mailserver.local
#
# 22:51:04 logout webserver.local
#
# 00:14:08 logout myworkstation.local
#
# 12:44:13 login mailserver.local
#
# 2020-05-11
# 14:41:50 logout webserver.local
#
# 23:39:08 login webserver.local
#
# 23:44:30 logout myworkstation.local
#
# 08:44:48 logout myworkstation.local
#
# 2020-05-12
# 19:59:51 logout webserver.local
#
# 2020-05-13
# 19:51:28 logout myworkstation.local
#
# 08:15:00 logout webserver.local
#
# 17:29:45 login mailserver.local
#
# 14:42:26 logout mailserver.local
#
# 16:14:00 login webserver.local
#
# 23:16:05 logout myworkstation.local
#
# 2020-05-14
# 01:40:47 login mailserver.local
#
# 19:58:11 logout myworkstation.local
#
# 23:27:27 login myworkstation.local
#
# 08:10:43 logout mailserver.local
#
# 2020-05-15
# 17:36:55 login mailserver.local
#
# 2020-05-16
# 17:12:50 logout webserver.local
#
# 00:16:48 logout mailserver.local
#
# 00:53:56 login mailserver.local
#
# 17:48:31 login myworkstation.local
#
# 2020-05-17
# 15:04:54 login mailserver.local
#
# 11:53:03 logout webserver.local
#
# 09:47:50 login webserver.local
#
# 2020-05-18
# 09:13:42 logout mailserver.local
#
# 18:36:02 login myworkstation.local
#
# 09:38:11 logout myworkstation.local
#
# 16:28:08 logout mailserver.local
#
# 03:40:45 login myworkstation.local
#
# 2020-05-19
# 15:21:23 logout myworkstation.local
#
# 02:16:02 login myworkstation.local
#
# 07:05:31 logout myworkstation.local
#
# 2020-05-20
# 08:56:07 logout myworkstation.local
#
# 2020-05-21
# 04:52:07 login webserver.local
#
# 05:32:23 login webserver.local
#
# 13:12:41 logout webserver.local
#
# 03:41:37 logout webserver.local
#
# 2020-05-22
# 15:20:48 login myworkstation.local
#
# 2020-05-23
# 07:57:29 login myworkstation.local
#
# 2020-05-24
# 06:55:34 logout webserver.local
#
# 14:11:24 login mailserver.local
#
# 03:27:33 login mailserver.local
#
# 01:09:52 login mailserver.local
#
# 2020-05-25
# 20:23:43 logout webserver.local
#
# 20:33:52 login webserver.local
#
# 2020-05-26
# 13:51:35 logout mailserver.local
#
# 22:13:42 login myworkstation.local
#
# 21:44:25 logout myworkstation.local
#
# 17:54:18 logout myworkstation.local
#
# 2020-05-27
# 11:35:12 logout webserver.local
#
# 07:59:24 login webserver.local
#
# 05:16:55 logout mailserver.local
#
# 20:24:24 logout webserver.local
#
# 09:26:27 login webserver.local
#
# 2020-05-28
# 04:21:54 logout webserver.local
#
# 2020-05-29
# 06:56:28 logout webserver.local
#
# 00:10:47 login webserver.local
#
# 23:52:45 login myworkstation.local
#
# 2020-05-30
# 09:15:53 logout mailserver.local
#
# 02:49:19 login mailserver.local
#
# 22:47:37 login mailserver.local
#
# 17:13:09 logout myworkstation.local
#
# 21:53:24 login webserver.local
#
# 23:37:45 logout mailserver.local
#
# 20:00:24 logout mailserver.local
#
# aprilmarie.ulatowski@freesurf.fr
# 2020-05-01
# 06:02:49 logout mailserver.local
#
# 16:39:06 logout myworkstation.local
#
# 12:25:29 logout webserver.local
#
# 18:49:30 login myworkstation.local
#
# 17:39:00 login webserver.local
#
# 2020-05-02
# 2020-05-03
# 09:50:02 login mailserver.local
#
# 23:46:01 logout mailserver.local
#
# 2020-05-04
# 07:03:27 logout myworkstation.local
#
# 12:01:16 logout webserver.local
#
# 13:46:08 logout mailserver.local
#
# 12:05:05 logout myworkstation.local
#
# 2020-05-05
# 14:16:13 login mailserver.local
#
# 10:32:12 login myworkstation.local
#
# 2020-05-06
# 14:52:54 login webserver.local
#
# 07:54:10 logout webserver.local
#
# 13:43:28 login myworkstation.local
#
# 21:33:21 login mailserver.local
#
# 02:59:48 logout myworkstation.local
#
# 03:57:12 logout webserver.local
#
# 15:41:05 login myworkstation.local
#
# 16:05:45 login myworkstation.local
#
# 2020-05-07
# 00:21:54 logout myworkstation.local
#
# 02:39:04 logout mailserver.local
#
# 2020-05-08
# 11:24:41 logout webserver.local
#
# 10:32:26 logout webserver.local
#
# 06:26:00 logout webserver.local
#
# 11:17:59 logout webserver.local
#
# 23:17:40 login mailserver.local
#
# 08:31:04 logout myworkstation.local
#
# 07:26:40 logout webserver.local
#
# 2020-05-09
# 20:01:19 login myworkstation.local
#
# 15:50:36 login myworkstation.local
#
# 2020-05-10
# 00:58:18 login webserver.local
#
# 17:16:24 login myworkstation.local
#
# 02:15:10 logout mailserver.local
#
# 13:05:28 login myworkstation.local
#
# 22:12:46 logout webserver.local
#
# 05:57:26 logout myworkstation.local
#
# 01:22:28 login myworkstation.local
#
# 2020-05-11
# 03:48:46 logout webserver.local
#
# 11:44:03 login webserver.local
#
# 13:56:37 logout mailserver.local
#
# 2020-05-12
# 10:12:58 login webserver.local
#
# 17:47:05 logout myworkstation.local
#
# 08:55:54 logout myworkstation.local
#
# 22:52:34 logout myworkstation.local
#
# 13:41:14 login webserver.local
#
# 10:44:31 logout myworkstation.local
#
# 2020-05-13
# 23:04:28 login mailserver.local
#
# 08:20:33 logout webserver.local
#
# 04:09:38 logout webserver.local
#
# 03:03:06 logout mailserver.local
#
# 2020-05-14
# 11:17:12 logout mailserver.local
#
# 21:44:07 logout myworkstation.local
#
# 12:42:00 login mailserver.local
#
# 2020-05-15
# 04:36:11 logout mailserver.local
#
# 05:27:36 logout myworkstation.local
#
# 04:08:31 login myworkstation.local
#
# 23:28:47 login mailserver.local
#
# 07:18:36 logout webserver.local
#
# 22:41:43 login webserver.local
#
# 2020-05-16
# 03:47:45 login webserver.local
#
# 06:26:39 logout webserver.local
#
# 2020-05-17
# 04:37:13 login mailserver.local
#
# 16:30:25 logout myworkstation.local
#
# 05:32:44 logout mailserver.local
#
# 04:32:19 login webserver.local
#
# 19:12:41 logout myworkstation.local
#
# 05:32:50 logout myworkstation.local
#
# 03:31:28 login mailserver.local
#
# 07:28:53 logout webserver.local
#
# 2020-05-18
# 09:34:46 logout webserver.local
#
# 15:32:43 login mailserver.local
#
# 03:22:22 login myworkstation.local
#
# 2020-05-19
# 15:35:30 login mailserver.local
#
# 15:53:21 logout webserver.local
#
# 2020-05-20
# 10:56:40 login myworkstation.local
#
# 19:27:29 login myworkstation.local
#
# 06:02:23 login myworkstation.local
#
# 2020-05-21
# 2020-05-22
# 2020-05-23
# 17:25:01 login webserver.local
#
# 17:31:45 logout webserver.local
#
# 13:49:41 login myworkstation.local
#
# 2020-05-24
# 14:39:14 logout webserver.local
#
# 18:58:09 logout webserver.local
#
# 2020-05-25
# 12:19:02 login mailserver.local
#
# 21:35:21 login mailserver.local
#
# 21:37:58 login webserver.local
#
# 2020-05-26
# 06:09:37 logout myworkstation.local
#
# 22:14:06 login myworkstation.local
#
# 22:30:29 login webserver.local
#
# 04:47:29 login myworkstation.local
#
# 2020-05-27
# 2020-05-28
# 08:53:45 login myworkstation.local
#
# 2020-05-29
# 05:47:10 logout myworkstation.local
#
# 2020-05-30
# 17:13:30 login myworkstation.local
#
# 07:19:09 logout webserver.local
#
# 20:34:41 logout myworkstation.local
#
# 19:56:47 logout webserver.local
#
# mieko.alcosiba@quiklinks.com
# 2020-05-01
# 15:59:30 login myworkstation.local
#
# 10:47:34 logout myworkstation.local
#
# 2020-05-02
# 05:12:47 logout webserver.local
#
# 19:17:56 login mailserver.local
#
# 14:48:50 login webserver.local
#
# 02:04:25 login mailserver.local
#
# 14:49:24 login mailserver.local
#
# 23:51:50 login mailserver.local
#
# 2020-05-03
# 05:39:02 login myworkstation.local
#
# 07:17:01 logout mailserver.local
#
# 21:33:48 logout webserver.local
#
# 16:34:03 logout webserver.local
#
# 2020-05-04
# 22:57:03 logout mailserver.local
#
# 2020-05-05
# 03:25:54 login webserver.local
#
# 02:35:02 login mailserver.local
#
# 10:34:35 login myworkstation.local
#
# 02:52:37 logout mailserver.local
#
# 2020-05-06
# 02:36:02 logout mailserver.local
#
# 07:07:33 login myworkstation.local
#
# 01:01:37 login mailserver.local
#
# 23:56:41 login myworkstation.local
#
# 07:11:16 login webserver.local
#
# 08:25:43 login mailserver.local
#
# 2020-05-07
# 06:18:40 logout myworkstation.local
#
# 2020-05-08
# 16:02:56 login webserver.local
#
# 08:54:09 login webserver.local
#
# 2020-05-09
# 11:19:22 logout webserver.local
#
# 13:36:59 login mailserver.local
#
# 2020-05-10
# 10:14:04 logout mailserver.local
#
# 07:06:48 login myworkstation.local
#
# 15:18:46 logout myworkstation.local
#
# 10:41:35 login myworkstation.local
#
# 21:07:10 logout myworkstation.local
#
# 21:48:08 logout mailserver.local
#
# 2020-05-11
# 10:22:26 logout webserver.local
#
# 14:57:42 logout myworkstation.local
#
# 16:04:55 login webserver.local
#
# 14:46:26 logout myworkstation.local
#
# 16:40:48 login myworkstation.local
#
# 11:29:51 logout webserver.local
#
# 2020-05-12
# 04:46:58 logout myworkstation.local
#
# 21:24:17 login myworkstation.local
#
# 06:16:52 login webserver.local
#
# 09:29:58 login myworkstation.local
#
# 16:46:16 login mailserver.local
# 2020-05-13
# 19:43:29 login myworkstation.local
#
# 15:11:34 logout myworkstation.local
#
# 03:38:57 login myworkstation.local
#
# 18:07:56 login myworkstation.local
#
# 06:43:31 login myworkstation.local
#
# 2020-05-14
# 04:21:07 login mailserver.local
#
# 02:41:54 login myworkstation.local
#
# 06:26:38 login mailserver.local
#
# 04:33:22 logout webserver.local
#
# 10:19:59 logout webserver.local
#
# 2020-05-15
# 05:14:36 logout myworkstation.local
#
# 11:27:40 login myworkstation.local
#
# 2020-05-16
# 19:03:07 logout myworkstation.local
#
# 00:16:11 login myworkstation.local
#
# 21:49:43 logout webserver.local
#
# 22:05:55 logout myworkstation.local
#
# 2020-05-17
# 00:57:21 logout myworkstation.local
#
# 22:21:12 logout mailserver.local
#
# 2020-05-18
# 00:24:03 logout mailserver.local
#
# 21:21:59 logout webserver.local
#
# 07:14:35 login mailserver.local
#
# 03:08:57 login myworkstation.local
#
# 18:25:58 logout myworkstation.local
#
# 22:32:53 logout mailserver.local
#
# 15:14:39 logout webserver.local
#
# 2020-05-19
# 06:19:01 login mailserver.local
#
# 09:10:55 login myworkstation.local
#
# 2020-05-20
# 19:52:22 login mailserver.local
#
# 2020-05-21
# 10:34:54 logout myworkstation.local
#
# 19:08:13 login myworkstation.local
#
# 09:08:06 logout webserver.local
#
# 22:18:35 logout myworkstation.local
#
# 19:06:50 login webserver.local
#
# 2020-05-22
# 02:26:53 logout myworkstation.local
#
# 07:54:30 login webserver.local
#
# 09:31:42 logout webserver.local
#
# 13:47:05 login myworkstation.local
#
# 10:01:19 login webserver.local
#
# 21:07:04 logout mailserver.local
#
# 18:01:54 login webserver.local
#
# 2020-05-23
# 17:59:37 login mailserver.local
#
# 08:17:37 login myworkstation.local
#
# 2020-05-24
# 10:35:41 login webserver.local
#
# 02:14:54 login myworkstation.local
#
# 09:56:58 logout webserver.local
#
# 15:35:07 login mailserver.local
#
# 2020-05-25
# 09:26:57 login myworkstation.local
#
# 12:45:11 logout mailserver.local
#
# 2020-05-26
# 10:09:54 login myworkstation.local
#
# 00:28:44 logout myworkstation.local
#
# 16:16:12 logout webserver.local
#
# 20:50:15 login mailserver.local
#
# 06:51:02 login myworkstation.local
#
# 2020-05-27
# 07:53:51 logout mailserver.local
#
# 17:53:36 logout webserver.local
#
# 02:42:40 logout mailserver.local
#
# 2020-05-28
# 07:07:59 login webserver.local
#
# 07:35:47 logout mailserver.local
#
# 04:21:02 login webserver.local
#
# 2020-05-29
# 01:42:45 logout myworkstation.local
#
# 05:10:35 logout mailserver.local
#
# 14:38:08 logout myworkstation.local
#
# 2020-05-30
# 14:42:15 login webserver.local
#
# 18:55:28 login mailserver.local
#
# 07:43:38 logout mailserver.local
#
# 06:12:20 logout mailserver.local
#
# melaina.gabeline@yahoo.com.mx
# 2020-05-01
# 06:51:17 login webserver.local
#
# 23:35:25 logout myworkstation.local
#
# 20:36:04 logout mailserver.local
#
# 14:46:28 login myworkstation.local
#
# 13:26:56 logout mailserver.local
#
# 18:10:17 logout webserver.local
#
# 2020-05-02
# 11:38:03 login mailserver.local
#
# 14:51:49 login myworkstation.local
#
# 12:19:54 logout myworkstation.local
#
# 13:30:23 login myworkstation.local
#
# 20:50:52 logout mailserver.local
#
# 03:18:45 logout webserver.local
#
# 03:49:53 logout webserver.local
#
# 07:58:37 login myworkstation.local
#
# 01:27:58 logout webserver.local
#
# 2020-05-03
# 08:15:50 login webserver.local
#
# 12:22:56 login myworkstation.local
#
# 10:39:59 logout myworkstation.local
#
# 23:48:50 login webserver.local
#
# 19:15:55 login webserver.local
#
# 07:51:17 logout webserver.local
#
# 22:27:18 login webserver.local
#
# 2020-05-04
# 23:24:00 logout mailserver.local
#
# 04:01:52 logout webserver.local
#
# 20:11:37 login myworkstation.local
#
# 20:47:21 login mailserver.local
#
# 02:35:34 login myworkstation.local
#
# 2020-05-05
# 06:17:09 login webserver.local
#
# 22:04:57 logout mailserver.local
#
# 12:39:38 login mailserver.local
#
# 22:00:19 logout mailserver.local
#
# 2020-05-06
# 05:25:28 login mailserver.local
#
# 23:50:07 logout webserver.local
#
# 04:09:21 logout myworkstation.local
#
# 13:40:18 login mailserver.local
#
# 12:39:30 login mailserver.local
#
# 2020-05-07
# 23:12:16 logout mailserver.local
#
# 20:28:15 login myworkstation.local
#
# 15:11:20 logout myworkstation.local
#
# 13:03:52 logout mailserver.local
#
# 01:12:40 logout mailserver.local
#
# 2020-05-08
# 19:33:20 logout mailserver.local
#
# 14:00:55 login mailserver.local
#
# 06:57:03 login webserver.local
#
# 12:07:16 login mailserver.local
#
# 22:40:56 login mailserver.local
#
# 2020-05-09
# 04:20:06 login myworkstation.local
#
# 18:53:42 login mailserver.local
#
# 18:55:11 login webserver.local
#
# 04:34:31 logout mailserver.local
#
# 03:04:02 login mailserver.local
#
# 2020-05-10
# 01:04:08 logout webserver.local
#
# 2020-05-11
# 20:54:39 logout myworkstation.local
#
# 2020-05-12
# 08:06:39 logout webserver.local
#
# 11:22:27 login myworkstation.local
#
# 10:19:37 logout mailserver.local
#
# 02:27:57 login mailserver.local
#
# 2020-05-13
# 04:54:25 login mailserver.local
#
# 14:36:29 login mailserver.local
#
# 2020-05-14
# 17:01:17 login webserver.local
#
# 2020-05-15
# 03:23:29 logout myworkstation.local
#
# 21:14:40 login mailserver.local
#
# 2020-05-16
# 08:09:55 logout myworkstation.local
#
# 09:40:48 login webserver.local
#
# 2020-05-17
# 17:07:06 logout mailserver.local
#
# 18:53:01 logout webserver.local
#
# 23:36:56 login myworkstation.local
#
# 08:23:02 logout mailserver.local
#
# 2020-05-18
# 05:29:03 logout webserver.local
#
# 05:08:51 logout myworkstation.local
#
# 00:28:05 logout myworkstation.local
#
# 10:40:48 logout webserver.local
#
# 2020-05-19
# 05:25:25 logout webserver.local
#
# 18:40:24 logout webserver.local
#
# 2020-05-20
# 07:22:57 logout webserver.local
#
# 22:32:10 logout myworkstation.local
#
# 14:49:19 login webserver.local
#
# 2020-05-21
# 08:59:08 logout webserver.local
#
# 05:29:29 logout myworkstation.local
#
# 05:39:53 login myworkstation.local
#
# 07:45:28 login myworkstation.local
#
# 2020-05-22
# 05:37:12 login mailserver.local
#
# 2020-05-23
# 00:44:42 login mailserver.local
#
# 14:59:22 login myworkstation.local
#
# 16:03:27 login myworkstation.local
#
# 18:17:12 login webserver.local
#
# 17:59:15 logout myworkstation.local
#
# 2020-05-24
# 19:14:54 login myworkstation.local
#
# 16:20:13 logout mailserver.local
#
# 17:32:29 login mailserver.local
#
# 20:41:25 login mailserver.local
#
# 2020-05-25
# 00:31:51 login mailserver.local
#
# 05:20:44 login webserver.local
#
# 09:43:31 logout mailserver.local
#
# 20:19:48 login myworkstation.local
#
# 08:06:56 login webserver.local
#
# 2020-05-26
# 21:36:22 login webserver.local
#
# 09:54:49 logout webserver.local
#
# 07:27:12 login myworkstation.local
#
# 09:55:14 login webserver.local
#
# 2020-05-27
# 01:21:31 logout mailserver.local
#
# 04:05:47 logout myworkstation.local
#
# 04:54:45 login mailserver.local
#
# 2020-05-28
# 13:43:46 logout myworkstation.local
#
# 01:22:09 logout mailserver.local
#
# 20:34:03 login myworkstation.local
#
# 2020-05-29
# 07:45:27 logout mailserver.local
#
# 22:46:44 login webserver.local
#
# 2020-05-30
# 13:47:54 login webserver.local
#
# 17:07:12 logout myworkstation.local
#
# 19:18:50 logout myworkstation.local
#
# rob.weinstock@miho-nakayama.com
# 2020-05-01
# 21:18:48 login myworkstation.local
#
# 04:56:40 login webserver.local
#
# 2020-05-02
# 13:24:05 logout myworkstation.local
#
# 07:41:03 login myworkstation.local
#
# 09:08:06 logout webserver.local
#
# 09:08:39 logout mailserver.local
#
# 22:33:08 logout webserver.local
#
# 2020-05-03
# 08:34:44 logout myworkstation.local
#
# 01:44:10 login myworkstation.local
#
# 13:01:28 logout webserver.local
#
# 2020-05-04
# 07:47:27 login myworkstation.local
#
# 2020-05-05
# 18:00:09 logout mailserver.local
#
# 09:40:27 logout myworkstation.local
#
# 2020-05-06
# 01:00:03 login myworkstation.local
#
# 14:20:21 login myworkstation.local
#
# 10:57:45 login myworkstation.local
#
# 2020-05-07
# 09:54:58 login mailserver.local
#
# 08:18:40 logout myworkstation.local
#
# 12:48:58 logout webserver.local
#
# 06:15:06 login mailserver.local
#
# 2020-05-08
# 18:08:19 logout webserver.local
#
# 2020-05-09
# 05:26:39 logout webserver.local
#
# 23:19:44 login webserver.local
#
# 18:11:35 login webserver.local
#
# 12:02:28 login mailserver.local
#
# 12:41:00 logout myworkstation.local
#
# 03:29:35 logout webserver.local
#
# 16:59:59 logout webserver.local
#
# 2020-05-10
# 22:25:19 logout webserver.local
#
# 19:13:52 logout webserver.local
#
# 15:10:50 login webserver.local
#
# 11:37:50 login myworkstation.local
#
# 2020-05-11
# 07:14:19 logout webserver.local
#
# 01:45:48 logout mailserver.local
#
# 07:48:57 login mailserver.local
#
# 2020-05-12
# 15:26:07 login mailserver.local
#
# 11:10:08 login myworkstation.local
#
# 08:55:11 login myworkstation.local
#
# 08:38:28 login mailserver.local
#
# 02:21:33 logout myworkstation.local
#
# 16:24:50 logout webserver.local
#
# 23:52:27 login webserver.local
#
# 23:15:50 logout webserver.local
#
# 15:21:05 logout webserver.local
#
# 17:37:54 logout mailserver.local
#
# 2020-05-13
# 11:09:33 login mailserver.local
#
# 05:27:46 login mailserver.local
#
# 20:36:24 logout webserver.local
#
# 19:43:41 logout mailserver.local
#
# 2020-05-14
# 20:13:31 login mailserver.local
#
# 04:59:33 logout myworkstation.local
#
# 12:10:28 login mailserver.local
#
# 07:30:18 logout webserver.local
#
# 12:19:51 login webserver.local
#
# 08:53:36 login webserver.local
#
# 20:32:04 login webserver.local
#
# 2020-05-15
# 09:37:19 logout webserver.local
#
# 15:01:38 login myworkstation.local
#
# 22:03:50 login myworkstation.local
#
# 19:11:37 logout webserver.local
#
# 2020-05-16
# 17:53:59 login webserver.local
#
# 18:08:50 logout mailserver.local
#
# 07:43:07 logout mailserver.local
#
# 08:19:43 logout webserver.local
#
# 2020-05-17
# 23:23:20 login mailserver.local
#
# 03:21:36 login webserver.local
#
# 11:29:48 logout myworkstation.local
#
# 13:05:24 login myworkstation.local
#
# 2020-05-18
# 13:30:57 logout myworkstation.local
#
# 08:44:17 logout mailserver.local
#
# 05:41:17 logout myworkstation.local
#
# 2020-05-19
# 23:52:23 login myworkstation.local
#
# 2020-05-20
# 03:48:03 login myworkstation.local
#
# 13:00:54 login mailserver.local
#
# 06:35:09 logout myworkstation.local
#
# 10:16:38 logout webserver.local
#
# 2020-05-21
# 17:26:34 logout mailserver.local
#
# 12:27:45 login webserver.local
#
# 2020-05-22
# 06:26:56 logout mailserver.local
#
# 20:34:13 logout webserver.local
#
# 2020-05-23
# 17:42:10 logout myworkstation.local
#
# 2020-05-24
# 05:51:58 login mailserver.local
#
# 2020-05-25
# 21:00:25 logout mailserver.local
#
# 03:02:05 login mailserver.local
#
# 06:50:03 login mailserver.local
#
# 04:30:58 login webserver.local
#
# 04:32:43 logout webserver.local
#
# 19:53:21 login webserver.local
#
# 02:27:41 login myworkstation.local
#
# 03:02:13 logout webserver.local
#
# 16:27:05 logout myworkstation.local
#
# 2020-05-26
# 11:22:06 logout mailserver.local
#
# 02:41:55 login mailserver.local
#
# 00:22:09 logout webserver.local
#
# 2020-05-27
# 07:14:43 login myworkstation.local
#
# 10:42:58 logout mailserver.local
#
# 14:19:02 login myworkstation.local
#
# 2020-05-28
# 14:32:18 logout webserver.local
#
# 21:55:10 logout webserver.local
#
# 01:50:11 login webserver.local
#
# 14:53:18 login myworkstation.local
#
# 17:13:34 logout mailserver.local
#
# 18:34:06 logout mailserver.local
#
# 2020-05-29
# 10:29:24 login webserver.local
#
# 16:06:10 logout myworkstation.local
#
# 2020-05-30
# 06:00:30 logout mailserver.local
#
# 17:32:30 logout mailserver.local
#
# remington.caffrey@estranet.it
# 2020-05-01
# 21:36:58 login mailserver.local
#
# 14:29:19 login webserver.local
#
# 14:48:21 login mailserver.local
#
# 2020-05-02
# 20:23:04 login mailserver.local
#
# 11:28:37 logout myworkstation.local
#
# 2020-05-03
# 17:47:20 login webserver.local
#
# 07:56:07 logout myworkstation.local
#
# 05:38:21 logout mailserver.local
#
# 05:54:14 login webserver.local
#
# 2020-05-04
# 19:45:25 login webserver.local
#
# 23:16:50 logout mailserver.local
#
# 19:44:13 logout mailserver.local
#
# 08:46:48 logout mailserver.local
#
# 19:24:44 login webserver.local
#
# 04:47:23 logout webserver.local
#
# 15:37:30 logout webserver.local
#
# 20:52:52 logout mailserver.local
#
# 2020-05-05
# 01:43:08 logout myworkstation.local
#
# 22:44:56 login webserver.local
#
# 15:51:02 logout webserver.local
#
# 02:04:30 logout mailserver.local
#
# 05:21:08 logout webserver.local
#
# 20:15:46 login mailserver.local
#
# 2020-05-06
# 04:22:29 logout myworkstation.local
#
# 02:48:23 login myworkstation.local
#
# 15:38:27 logout webserver.local
#
# 2020-05-07
# 07:16:53 logout webserver.local
#
# 01:03:07 logout webserver.local
#
# 07:01:45 logout myworkstation.local
#
# 00:32:24 logout myworkstation.local
#
# 2020-05-08
# 20:42:12 logout myworkstation.local
#
# 2020-05-09
# 16:46:34 login mailserver.local
#
# 02:28:24 logout myworkstation.local
#
# 2020-05-10
# 01:21:29 logout webserver.local
#
# 05:36:12 login webserver.local
#
# 2020-05-11
# 04:59:03 login mailserver.local
#
# 2020-05-12
# 2020-05-13
# 19:47:31 login mailserver.local
#
# 00:54:06 login mailserver.local
#
# 2020-05-14
# 2020-05-15
# 05:16:28 logout myworkstation.local
#
# 22:17:22 logout webserver.local
#
# 07:21:18 login mailserver.local
#
# 07:10:47 login mailserver.local
#
# 21:33:36 logout mailserver.local
#
# 21:19:05 login myworkstation.local
#
# 21:28:17 logout myworkstation.local
#
# 2020-05-16
# 00:56:40 login mailserver.local
#
# 20:58:19 logout mailserver.local
#
# 11:41:54 login myworkstation.local
#
# 2020-05-17
# 08:00:22 logout mailserver.local
#
# 2020-05-18
# 2020-05-19
# 09:15:21 login webserver.local
#
# 07:06:26 login myworkstation.local
#
# 19:10:34 login mailserver.local
#
# 2020-05-20
# 06:32:45 logout myworkstation.local
#
# 09:21:41 login webserver.local
#
# 23:51:57 logout myworkstation.local
#
# 2020-05-21
# 00:38:05 logout mailserver.local
#
# 06:40:30 logout webserver.local
#
# 2020-05-22
# 03:53:31 logout webserver.local
#
# 07:12:42 logout webserver.local
#
# 2020-05-23
# 02:37:48 logout webserver.local
# 23:34:37 login mailserver.local
#
# 21:06:34 login myworkstation.local
#
# 2020-05-24
# 08:11:35 logout myworkstation.local
#
# 08:26:23 login mailserver.local
#
# 15:30:55 logout mailserver.local
#
# 2020-05-25
# 06:26:27 login mailserver.local
#
# 03:21:43 logout webserver.local
#
# 01:37:45 login myworkstation.local
#
# 01:15:02 login myworkstation.local
#
# 2020-05-26
# 14:12:47 logout mailserver.local
#
# 15:28:29 login myworkstation.local
#
# 04:25:57 login webserver.local
#
# 04:48:50 login webserver.local
#
# 2020-05-27
# 18:39:38 logout webserver.local
#
# 18:31:42 logout webserver.local
#
# 11:25:38 logout myworkstation.local
#
# 08:33:30 login mailserver.local
#
# 2020-05-28
# 05:17:21 login myworkstation.local
#
# 01:31:22 logout mailserver.local
#
# 04:40:30 logout webserver.local
#
# 06:35:27 logout mailserver.local
#
# 20:05:03 login webserver.local
#
# 04:59:19 login mailserver.local
#
# 2020-05-29
# 08:13:10 logout mailserver.local
#
# 19:26:26 login webserver.local
#
# 22:26:46 logout myworkstation.local
#
# 20:55:58 logout webserver.local
#
# 19:05:10 login webserver.local
#
# 10:22:24 login myworkstation.local
#
# 19:33:20 login webserver.local
#
# 2020-05-30
# 17:45:39 login webserver.local
#
# 13:35:13 login webserver.local
#
# 08:30:48 login mailserver.local
#
# 13:26:31 login mailserver.local
#
# 10:28:28 login myworkstation.local
#
# daysha.karshner@blacksburg.net
# 2020-05-01
# 13:16:14 login myworkstation.local
#
# 17:55:00 login myworkstation.local
#
# 01:55:52 login mailserver.local
#
# 09:04:51 login webserver.local
#
# 2020-05-02
# 12:37:46 logout myworkstation.local
#
# 17:45:21 logout mailserver.local
#
# 19:57:12 login mailserver.local
#
# 09:53:53 login mailserver.local
#
# 02:37:00 logout webserver.local
#
# 23:00:35 login mailserver.local
#
# 2020-05-03
# 04:03:42 logout mailserver.local
#
# 02:00:52 login myworkstation.local
#
# 13:59:06 logout myworkstation.local
#
# 2020-05-04
# 15:14:41 logout myworkstation.local
#
# 18:41:01 login webserver.local
#
# 07:12:13 login mailserver.local
#
# 17:55:06 login mailserver.local
#
# 04:14:32 login mailserver.local
#
# 2020-05-05
# 17:45:33 login mailserver.local
#
# 01:19:43 login mailserver.local
#
# 03:17:30 login webserver.local
#
# 2020-05-06
# 13:07:31 logout myworkstation.local
#
# 07:46:27 login myworkstation.local
#
# 2020-05-07
# 15:39:55 login myworkstation.local
#
# 23:51:41 login myworkstation.local
#
# 2020-05-08
# 07:18:37 logout webserver.local
#
# 19:38:46 logout myworkstation.local
#
# 23:46:27 logout mailserver.local
#
# 11:12:47 logout mailserver.local
#
# 2020-05-09
# 20:10:19 logout myworkstation.local
#
# 22:59:16 logout myworkstation.local
#
# 09:52:36 logout mailserver.local
#
# 00:54:56 login myworkstation.local
#
# 2020-05-10
# 03:37:03 logout mailserver.local
#
# 2020-05-11
# 18:44:38 logout myworkstation.local
#
# 09:48:46 login mailserver.local
#
# 16:19:53 logout webserver.local
#
# 07:01:41 logout webserver.local
#
# 2020-05-12
# 2020-05-13
# 12:21:53 logout myworkstation.local
#
# 12:33:07 logout webserver.local
#
# 16:40:10 logout webserver.local
#
# 09:42:42 logout webserver.local
#
# 22:44:32 logout myworkstation.local
#
# 2020-05-14
# 08:23:27 login webserver.local
#
# 04:59:30 login mailserver.local
#
# 08:21:15 login mailserver.local
#
# 2020-05-15
# 2020-05-16
# 02:03:21 logout myworkstation.local
#
# 13:44:39 login mailserver.local
#
# 2020-05-17
# 10:06:33 login myworkstation.local
#
# 06:07:55 login webserver.local
#
# 2020-05-18
# 22:09:39 logout webserver.local
#
# 21:08:27 logout mailserver.local
#
# 08:13:43 login myworkstation.local
#
# 2020-05-19
# 05:10:55 logout myworkstation.local
#
# 04:40:30 login webserver.local
#
# 2020-05-20
# 16:56:22 login webserver.local
#
# 22:18:47 logout webserver.local
#
# 2020-05-21
# 02:37:09 logout myworkstation.local
#
# 16:35:34 login myworkstation.local
#
# 12:34:35 logout webserver.local
#
# 2020-05-22
# 22:37:04 login webserver.local
#
# 00:36:16 login myworkstation.local
#
# 14:09:11 logout myworkstation.local
#
# 11:19:42 logout mailserver.local
#
# 17:50:47 logout myworkstation.local
#
# 17:55:34 login myworkstation.local
#
# 10:28:17 logout myworkstation.local
#
# 2020-05-23
# 2020-05-24
# 01:06:39 logout mailserver.local
#
# 05:54:53 logout webserver.local
#
# 02:26:44 logout webserver.local
#
# 11:06:27 logout mailserver.local
#
# 14:42:55 logout myworkstation.local
#
# 2020-05-25
# 22:30:40 login mailserver.local
#
# 08:35:47 login mailserver.local
#
# 18:24:29 login myworkstation.local
#
# 20:11:31 logout webserver.local
#
# 09:11:30 logout myworkstation.local
#
# 18:26:18 logout webserver.local
#
# 01:04:34 logout myworkstation.local
#
# 18:00:45 logout mailserver.local
#
# 2020-05-26
# 20:26:07 login myworkstation.local
#
# 21:35:34 logout mailserver.local
#
# 00:46:14 login myworkstation.local
#
# 2020-05-27
# 15:17:15 login myworkstation.local
#
# 01:51:06 login webserver.local
#
# 06:04:15 logout webserver.local
#
# 12:03:03 logout mailserver.local
#
# 11:07:02 login myworkstation.local
#
# 2020-05-28
# 02:11:36 login myworkstation.local
#
# 22:37:32 logout webserver.local
#
# 2020-05-29
# 08:51:10 login mailserver.local
#
# 10:37:04 logout webserver.local
#
# 06:01:11 login myworkstation.local
#
# 05:19:29 login myworkstation.local
#
# 10:19:42 login webserver.local
#
# 2020-05-30
# 09:25:11 login mailserver.local
#
# 03:10:15 logout myworkstation.local
#
# 19:59:53 logout myworkstation.local
#
# 10:06:17 login mailserver.local
#
# queen.sirucek@mail2emergency.com
# 2020-05-01
# 23:35:36 login webserver.local
#
# 13:16:29 login mailserver.local
#
# 02:58:02 login myworkstation.local
#
# 17:19:21 logout webserver.local
#
# 2020-05-02
# 11:36:17 logout webserver.local
#
# 2020-05-03
# 07:12:31 login webserver.local
#
# 2020-05-04
# 23:52:03 logout mailserver.local
#
# 21:54:42 login mailserver.local
#
# 06:41:12 logout webserver.local
#
# 04:41:56 logout webserver.local
#
# 01:15:20 login mailserver.local
#
# 11:37:24 login mailserver.local
#
# 16:08:27 logout mailserver.local
#
# 2020-05-05
# 22:53:59 logout webserver.local
#
# 20:57:53 login webserver.local
#
# 17:41:24 login myworkstation.local
#
# 19:48:22 login myworkstation.local
#
# 08:03:58 logout mailserver.local
#
# 2020-05-06
# 01:34:45 login webserver.local
#
# 09:59:18 logout myworkstation.local
#
# 08:47:31 login myworkstation.local
#
# 20:35:33 login myworkstation.local
#
# 2020-05-07
# 16:12:18 logout mailserver.local
#
# 18:58:16 logout myworkstation.local
#
# 12:20:47 logout mailserver.local
#
# 03:44:37 logout mailserver.local
#
# 2020-05-08
# 04:25:04 login mailserver.local
#
# 10:55:09 login mailserver.local
#
# 01:34:55 logout webserver.local
#
# 2020-05-09
# 00:40:28 logout mailserver.local
#
# 23:19:56 login myworkstation.local
#
# 06:49:52 logout myworkstation.local
#
# 22:01:06 logout mailserver.local
#
# 00:50:14 logout mailserver.local
#
# 14:19:27 logout webserver.local
#
# 2020-05-10
# 23:18:01 logout webserver.local
#
# 04:49:26 login webserver.local
#
# 15:32:41 logout mailserver.local
#
# 2020-05-11
# 22:45:13 logout webserver.local
#
# 18:44:12 login myworkstation.local
#
# 23:53:29 login webserver.local
#
# 18:40:37 logout webserver.local
#
# 03:07:43 logout mailserver.local
#
# 2020-05-12
# 12:21:00 login webserver.local
#
# 09:24:30 login mailserver.local
#
# 10:15:50 login webserver.local
#
# 11:48:07 logout myworkstation.local
#
# 05:25:58 logout myworkstation.local
#
# 2020-05-13
# 21:03:24 login myworkstation.local
#
# 08:27:04 login mailserver.local
#
# 21:18:44 logout mailserver.local
#
# 20:31:12 logout webserver.local
#
# 11:42:55 logout mailserver.local
#
# 2020-05-14
# 10:12:57 login mailserver.local
#
# 00:16:25 login myworkstation.local
#
# 10:47:04 logout webserver.local
#
# 2020-05-15
# 09:54:42 login mailserver.local
#
# 22:29:51 login myworkstation.local
#
# 11:40:33 logout webserver.local
#
# 07:41:14 logout webserver.local
#
# 2020-05-16
# 08:37:59 logout mailserver.local
#
# 05:37:13 login webserver.local
#
# 20:09:45 login webserver.local
#
# 2020-05-17
# 19:15:27 login myworkstation.local
#
# 21:34:55 logout myworkstation.local
#
# 19:34:49 logout myworkstation.local
#
# 04:17:28 logout webserver.local
#
# 2020-05-18
# 01:12:59 logout mailserver.local
#
# 01:13:00 logout myworkstation.local
#
# 19:23:51 logout myworkstation.local
#
# 2020-05-19
# 15:07:18 logout myworkstation.local
#
# 15:03:36 login webserver.local
#
# 03:18:58 logout myworkstation.local
#
# 2020-05-20
# 13:25:00 login mailserver.local
#
# 05:15:08 login myworkstation.local
#
# 00:06:04 logout webserver.local
#
# 2020-05-21
# 21:08:56 logout mailserver.local
#
# 13:07:27 login mailserver.local
#
# 18:44:16 logout webserver.local
#
# 06:40:38 logout mailserver.local
#
# 2020-05-22
# 2020-05-23
# 04:50:07 login mailserver.local
#
# 10:27:39 logout mailserver.local
#
# 13:16:54 logout webserver.local
#
# 06:59:41 login mailserver.local
#
# 18:04:45 logout webserver.local
#
# 2020-05-24
# 11:16:07 logout myworkstation.local
#
# 14:49:53 logout myworkstation.local
#
# 04:36:52 logout webserver.local
#
# 03:38:36 login webserver.local
#
# 00:07:31 logout mailserver.local
#
# 2020-05-25
# 01:55:51 login myworkstation.local
#
# 19:35:21 login mailserver.local
#
# 15:19:59 logout myworkstation.local
#
# 17:10:15 login mailserver.local
#
# 2020-05-26
# 04:30:36 logout webserver.local
#
# 18:12:50 login mailserver.local
#
# 12:35:56 login mailserver.local
#
# 2020-05-27
# 19:10:38 logout myworkstation.local
#
# 14:45:20 logout mailserver.local
#
# 18:03:42 login webserver.local
#
# 00:16:29 logout mailserver.local
#
# 13:20:09 login mailserver.local
#
# 14:39:26 login mailserver.local
#
# 10:43:16 login webserver.local
#
# 2020-05-28
# 15:55:05 logout myworkstation.local
#
# 18:47:23 logout myworkstation.local
#
# 2020-05-29
# 18:12:40 logout mailserver.local
#
# 08:16:14 logout webserver.local
#
# 2020-05-30
# arti.karshner@mail2perry.com
# 2020-05-01
# 02:24:30 login webserver.local
#
# 14:22:53 logout webserver.local
#
# 01:51:58 login webserver.local
#
# 16:59:03 logout myworkstation.local
#
# 20:32:28 logout myworkstation.local
#
# 13:04:48 login myworkstation.local
#
# 2020-05-02
# 22:53:53 login mailserver.local
#
# 12:44:01 login mailserver.local
#
# 17:50:36 login myworkstation.local
#
# 2020-05-03
# 2020-05-04
# 05:31:30 logout myworkstation.local
#
# 18:27:05 logout webserver.local
#
# 2020-05-05
# 02:26:15 login mailserver.local
#
# 21:58:59 logout mailserver.local
#
# 06:35:10 logout webserver.local
#
# 10:55:43 login webserver.local
#
# 02:34:17 login webserver.local
#
# 02:54:12 logout myworkstation.local
#
# 12:15:18 login webserver.local
#
# 01:23:25 login webserver.local
#
# 2020-05-06
# 05:15:08 login mailserver.local
#
# 08:15:59 logout myworkstation.local
#
# 20:40:03 logout myworkstation.local
#
# 02:47:17 logout mailserver.local
#
# 2020-05-07
# 17:29:38 login webserver.local
#
# 2020-05-08
# 17:24:42 login webserver.local
#
# 17:45:07 logout mailserver.local
#
# 01:39:01 logout webserver.local
#
# 11:28:18 login webserver.local
#
# 2020-05-09
# 07:53:14 logout webserver.local
#
# 07:05:15 login mailserver.local
#
# 09:05:09 login myworkstation.local
#
# 2020-05-10
# 01:31:59 logout myworkstation.local
#
# 00:41:19 login webserver.local
#
# 17:43:59 logout myworkstation.local
#
# 17:26:04 login webserver.local
#
# 16:14:58 login mailserver.local
#
# 2020-05-11
# 22:06:04 login myworkstation.local
# 2020-05-12
# 07:13:20 login webserver.local
#
# 2020-05-13
# 11:57:16 login mailserver.local
#
# 06:29:39 logout myworkstation.local
#
# 2020-05-14
# 16:31:34 logout webserver.local
#
# 01:56:32 login webserver.local
#
# 10:23:36 logout webserver.local
#
# 03:45:10 login myworkstation.local
#
# 2020-05-15
# ...
#
# 09:39:27 login mailserver.local
# 11:06:35 logout myworkstation.local
#
# 08:33:58 logout myworkstation.local
#
# 2020-05-03
# 07:00:03 logout webserver.local
#
# 17:19:39 logout myworkstation.local
#
# 02:37:52 logout webserver.local
#
# 2020-05-04
# 03:36:55 login mailserver.local
#
# 12:05:14 login mailserver.local
#
# 05:25:44 login webserver.local
#
# 14:14:34 logout myworkstation.local
#
# 03:20:29 login mailserver.local
#
# 10:49:43 login myworkstation.local
#
# 2020-05-05
# 08:20:11 login webserver.local
#
# 18:56:57 login myworkstation.local
#
# 07:46:43 logout myworkstation.local
#
# 2020-05-06
# 15:05:56 login myworkstation.local
#
# 00:41:58 logout webserver.local
#
# 14:15:43 login myworkstation.local
#
# 2020-05-07
# 11:47:39 logout webserver.local
#
# 21:47:07 login mailserver.local
#
# 02:59:42 login myworkstation.local
#
# 10:28:58 login webserver.local
#
# 05:18:52 login webserver.local
#
# 10:22:33 logout mailserver.local
#
# 20:03:32 login webserver.local
#
# 2020-05-08
# 20:55:39 login mailserver.local
#
# 19:38:33 login webserver.local
#
# 09:07:10 logout myworkstation.local
#
# 18:38:03 logout myworkstation.local
#
# 06:50:42 logout webserver.local
#
# 22:11:00 login myworkstation.local
#
# 2020-05-09
# 11:16:00 logout mailserver.local
#
# 00:36:03 logout webserver.local
#
# 10:34:30 logout myworkstation.local
#
# 19:08:23 logout webserver.local
#
# 17:55:59 login myworkstation.local
#
# 2020-05-10
# 01:25:25 logout mailserver.local
#
# 08:29:56 logout myworkstation.local
#
# 20:52:15 login myworkstation.local
#
# 19:57:59 login mailserver.local
#
# 00:51:02 logout mailserver.local
#
# 06:43:23 login mailserver.local
#
# 2020-05-11
# 06:10:02 login myworkstation.local
#
# 18:23:14 login myworkstation.local
#
# 2020-05-12
# 00:06:50 login myworkstation.local
#
# 17:13:31 login mailserver.local
#
# 12:52:29 login webserver.local
#
# 23:05:53 login webserver.local
#
# 23:34:43 logout myworkstation.local
#
# 2020-05-13
# 02:08:45 logout myworkstation.local
#
# 01:58:01 login myworkstation.local
#
# 20:35:46 logout myworkstation.local
#
# 2020-05-14
# 17:39:03 login mailserver.local
#
# 2020-05-15
# 03:29:01 logout myworkstation.local
#
# 13:52:42 login myworkstation.local
#
# 16:33:20 logout webserver.local
#
# 2020-05-16
# 08:01:49 logout myworkstation.local
#
# 07:11:54 logout myworkstation.local
#
# 2020-05-17
# 11:45:52 logout mailserver.local
#
# 14:03:59 logout webserver.local
#
# 2020-05-18
# 11:13:33 login webserver.local
#
# 2020-05-19
# 04:23:22 login mailserver.local
#
# 12:16:51 login webserver.local
#
# 2020-05-20
# 11:52:25 logout webserver.local
#
# 07:41:16 logout webserver.local
#
# 16:58:49 logout mailserver.local
#
# 06:10:59 logout webserver.local
#
# 01:33:59 logout myworkstation.local
#
# 23:39:50 login webserver.local
#
# 2020-05-21
# 16:30:59 login mailserver.local
#
# 20:47:58 logout mailserver.local
#
# 12:49:24 login webserver.local
#
# 16:37:43 logout myworkstation.local
#
# 2020-05-22
# 11:44:14 login webserver.local
#
# 17:43:31 logout mailserver.local
#
# 2020-05-23
# 15:57:11 login myworkstation.local
#
# 01:09:07 login webserver.local
#
# 10:46:28 logout myworkstation.local
#
# 2020-05-24
# 11:47:51 login mailserver.local
#
# 00:54:33 login mailserver.local
#
# 03:00:16 logout webserver.local
#
# 2020-05-25
# 18:44:43 logout mailserver.local
#
# 08:17:48 login mailserver.local
#
# 05:32:29 logout myworkstation.local
#
# 2020-05-26
# 09:42:58 login webserver.local
#
# 11:19:35 logout myworkstation.local
#
# 11:54:38 logout myworkstation.local
#
# 00:31:58 logout myworkstation.local
#
# 2020-05-27
# 01:02:56 login myworkstation.local
#
# 02:43:47 logout myworkstation.local
#
# 19:04:51 login myworkstation.local
#
# 2020-05-28
# 01:40:24 login mailserver.local
#
# 05:19:21 logout webserver.local
#
# 07:01:45 login myworkstation.local
#
# 19:19:32 login myworkstation.local
#
# 11:54:20 login mailserver.local
#
# 19:10:26 login mailserver.local
#
# 2020-05-29
# 23:34:06 logout mailserver.local
#
# 18:59:51 logout mailserver.local
#
# 06:36:21 login webserver.local
#
# 2020-05-30
# 00:18:12 login mailserver.local
#
# 21:45:12 logout myworkstation.local
#
# 07:46:29 logout mailserver.local
#
# 17:41:53 logout myworkstation.local
#
# catherina.rowles@mail2zambia.com
# 2020-05-01
# 06:16:15 logout webserver.local
#
# 22:52:07 logout mailserver.local
#
# 2020-05-02
# 04:35:23 logout webserver.local
#
# 12:11:27 login myworkstation.local
#
# 14:50:18 logout myworkstation.local
#
# 02:59:07 logout myworkstation.local
#
# 2020-05-03
# 08:53:45 login myworkstation.local
#
# 2020-05-04
# 15:32:31 logout myworkstation.local
#
# 04:24:03 login mailserver.local
#
# 08:44:54 login mailserver.local
#
# 07:11:14 logout myworkstation.local
#
# 02:32:35 login webserver.local
#
# 22:57:42 logout myworkstation.local
#
# 2020-05-05
# 20:32:15 logout mailserver.local
#
# 11:06:16 logout myworkstation.local
#
# 2020-05-06
# 02:26:22 login mailserver.local
#
# 06:22:18 logout myworkstation.local
#
# 2020-05-07
# 11:02:01 login myworkstation.local
#
# 2020-05-08
# 23:37:28 logout webserver.local
#
# 22:57:12 logout myworkstation.local
#
# 2020-05-09
# 20:24:06 login webserver.local
#
# 09:57:36 login myworkstation.local
#
# 18:59:34 logout myworkstation.local
#
# 2020-05-10
# 18:43:47 logout myworkstation.local
#
# 21:42:57 logout mailserver.local
#
# 07:29:20 logout webserver.local
#
# 06:29:11 login mailserver.local
#
# 23:45:38 login myworkstation.local
#
# 01:39:59 login webserver.local
#
# 2020-05-11
# 11:39:01 logout webserver.local
#
# 14:30:21 logout webserver.local
#
# 2020-05-12
# 05:20:03 logout myworkstation.local
#
# 02:05:24 logout mailserver.local
#
# 14:01:26 login myworkstation.local
#
# 17:12:23 logout mailserver.local
#
# 18:28:14 logout mailserver.local
#
# 2020-05-13
# 22:37:24 login mailserver.local
#
# 23:57:35 login mailserver.local
#
# 05:10:37 logout webserver.local
#
# 14:12:45 login myworkstation.local
#
# 2020-05-14
# 02:12:05 logout mailserver.local
#
# 02:27:27 login webserver.local
#
# 01:01:24 login webserver.local
#
# 08:31:18 login myworkstation.local
#
# 2020-05-15
# 2020-05-16
# 22:25:54 logout mailserver.local
#
# 22:28:22 logout mailserver.local
#
# 08:41:54 login mailserver.local
#
# 2020-05-17
# 16:33:20 login myworkstation.local
#
# 00:10:07 logout mailserver.local
#
# 2020-05-18
# 03:27:18 login webserver.local
#
# 00:10:08 logout mailserver.local
#
# 06:20:31 logout myworkstation.local
#
# 08:28:58 login mailserver.local
#
# 07:22:52 logout myworkstation.local
#
# 2020-05-19
# 02:48:54 logout webserver.local
#
# 01:35:25 logout myworkstation.local
#
# 15:50:38 login webserver.local
#
# 04:36:45 logout myworkstation.local
#
# 00:30:10 login webserver.local
#
# 07:50:24 login webserver.local
#
# 08:20:22 logout myworkstation.local
#
# 12:01:49 logout mailserver.local
#
# 16:24:02 logout webserver.local
#
# 2020-05-20
# 15:34:53 login mailserver.local
#
# 14:36:06 login mailserver.local
#
# 09:04:09 login mailserver.local
#
# 00:43:20 logout myworkstation.local
#
# 18:44:37 logout mailserver.local
#
# 06:02:40 logout myworkstation.local
#
# 15:10:39 login webserver.local
#
# 2020-05-21
# 18:13:29 logout myworkstation.local
#
# 11:56:34 login myworkstation.local
#
# 13:49:33 login myworkstation.local
#
# 17:30:07 logout webserver.local
#
# 16:37:37 login mailserver.local
#
# 12:35:27 logout webserver.local
#
# 17:22:57 login webserver.local
#
# 2020-05-22
# 22:44:42 logout myworkstation.local
#
# 16:51:28 logout mailserver.local
#
# 14:04:00 logout myworkstation.local
#
# 08:29:48 logout myworkstation.local
#
# 08:50:41 login mailserver.local
#
# 2020-05-23
# 00:53:32 login myworkstation.local
#
# 2020-05-24
# 14:13:33 logout mailserver.local
#
# 15:48:01 logout myworkstation.local
#
# 2020-05-25
# 19:18:04 logout mailserver.local
#
# 12:53:16 logout myworkstation.local
#
# 00:53:56 logout myworkstation.local
#
# 2020-05-26
# 13:31:35 logout myworkstation.local
#
# 17:23:59 login myworkstation.local
#
# 2020-05-27
# 05:40:53 login webserver.local
#
# 2020-05-28
# 21:07:29 logout mailserver.local
#
# 00:34:29 login myworkstation.local
#
# 03:09:28 logout myworkstation.local
#
# 16:24:16 logout mailserver.local
#
# 00:29:55 logout mailserver.local
#
# 22:18:38 logout mailserver.local
#
# 19:58:25 logout myworkstation.local
#
# 12:58:20 login mailserver.local
#
# 03:06:16 logout mailserver.local
#
# 2020-05-29
# 00:25:58 login webserver.local
#
# 00:35:20 logout mailserver.local
#
# 12:05:26 login webserver.local
#
# 2020-05-30
# 13:59:38 login myworkstation.local
#
# 13:00:40 logout mailserver.local
#
# 11:45:46 logout myworkstation.local
#
# 07:21:19 logout myworkstation.local
#
# sevan.stephco@miho-nakayama.com
# 2020-05-01
# 16:50:00 logout mailserver.local
#
# 03:11:33 login myworkstation.local
#
# 2020-05-02
# 18:40:49 logout webserver.local
#
# 14:50:40 logout mailserver.local
#
# 17:15:02 logout webserver.local
#
# 2020-05-03
# 14:28:57 logout mailserver.local
#
# 14:31:11 login webserver.local
#
# 20:41:15 login mailserver.local
#
# 2020-05-04
# 20:57:45 logout webserver.local
#
# 2020-05-05
# 17:15:42 login myworkstation.local
#
# 2020-05-06
# 04:07:38 logout mailserver.local
#
# 12:30:44 login mailserver.local
#
# 2020-05-07
# 01:24:04 logout webserver.local
#
# 05:35:04 login myworkstation.local
#
# 19:16:03 logout myworkstation.local
#
# 2020-05-08
# 19:34:09 logout mailserver.local
#
# 08:59:54 login mailserver.local
#
# 01:12:33 login mailserver.local
#
# 14:15:09 login myworkstation.local
#
# 2020-05-09
# 11:39:15 login webserver.local
#
# 05:52:13 logout myworkstation.local
#
# 10:35:17 login myworkstation.local
#
# 06:36:03 login mailserver.local
#
# 06:19:14 logout webserver.local
#
# 2020-05-10
# 22:06:48 logout myworkstation.local
#
# 07:14:19 logout myworkstation.local
#
# 07:51:29 login myworkstation.local
#
# 2020-05-11
# 03:21:20 logout webserver.local
#
# 2020-05-12
# 14:44:08 logout webserver.local
#
# 2020-05-13
# 07:02:48 logout webserver.local
#
# 01:13:45 login myworkstation.local
#
# 08:47:22 login webserver.local
#
# 23:59:29 login mailserver.local
#
# 03:26:31 logout mailserver.local
#
# 05:17:28 login myworkstation.local
#
# 2020-05-14
# 01:12:01 login mailserver.local
#
# 03:06:45 logout myworkstation.local
#
# 22:57:19 logout mailserver.local
#
# 23:15:23 login mailserver.local
#
# 12:03:05 logout mailserver.local
#
# 2020-05-15
# 10:54:11 logout mailserver.local
#
# 02:08:18 logout webserver.local
#
# 17:16:14 login myworkstation.local
#
# 17:32:23 logout mailserver.local
#
# 07:08:32 logout myworkstation.local
#
# 2020-05-16
# 20:10:37 logout webserver.local
#
# 23:01:14 logout mailserver.local
#
# 13:50:19 login myworkstation.local
#
# 02:40:13 logout webserver.local
#
# 2020-05-17
# 21:46:23 logout mailserver.local
#
# 17:00:37 logout mailserver.local
#
# 02:16:34 login myworkstation.local
#
# 21:53:03 login myworkstation.local
#
# 19:54:54 login myworkstation.local
#
# 2020-05-18
# 18:57:27 login webserver.local
#
# 00:05:45 login webserver.local
#
# 01:53:30 logout mailserver.local
#
# 2020-05-19
# 2020-05-20
# 05:40:55 login myworkstation.local
#
# 15:23:32 login myworkstation.local
#
# 08:56:12 login webserver.local
#
# 2020-05-21
# 02:04:40 logout mailserver.local
#
# 20:48:53 logout mailserver.local
#
# 03:19:30 logout myworkstation.local
#
# 21:59:26 logout webserver.local
#
# 03:09:13 login myworkstation.local
#
# 09:40:28 logout myworkstation.local
#
# 2020-05-22
# 00:27:52 login webserver.local
#
# 14:55:13 login mailserver.local
#
# 21:45:17 logout myworkstation.local
#
# 05:06:53 logout webserver.local
#
# 22:53:40 logout mailserver.local
#
# 2020-05-23
# 17:53:36 login myworkstation.local
# 17:10:41 login myworkstation.local
#
# 14:26:54 logout webserver.local
#
# 10:23:33 logout webserver.local
#
# 11:07:34 login myworkstation.local
#
# 2020-05-24
# 12:32:37 login myworkstation.local
#
# 03:13:13 logout mailserver.local
#
# 22:40:00 login myworkstation.local
#
# 15:29:00 login mailserver.local
#
# 2020-05-25
# 09:52:49 login webserver.local
#
# 13:03:42 login myworkstation.local
#
# 18:42:36 logout mailserver.local
#
# 2020-05-26
# 07:34:42 logout myworkstation.local
#
# 22:27:47 logout webserver.local
#
# 13:29:07 logout myworkstation.local
#
# 04:21:49 logout webserver.local
#
# 19:21:13 login myworkstation.local
#
# 18:41:35 logout mailserver.local
#
# 06:18:26 login myworkstation.local
#
# 18:14:35 logout myworkstation.local
#
# 2020-05-27
# 01:22:12 login myworkstation.local
#
# 21:30:49 logout webserver.local
#
# 05:02:24 login myworkstation.local
#
# 2020-05-28
# 12:21:24 logout mailserver.local
#
# 2020-05-29
# 12:21:10 login myworkstation.local
#
# 05:49:34 login mailserver.local
#
# 18:18:51 logout myworkstation.local
#
# 11:09:35 logout mailserver.local
#
# 15:06:13 login webserver.local
#
# 2020-05-30
# 01:08:30 logout mailserver.local
#
# 11:37:38 login mailserver.local
#
# ronica.thistle@freesurf.fr
# 2020-05-01
# 03:32:42 login webserver.local
#
# 09:40:04 logout webserver.local
#
# 03:04:11 logout webserver.local
#
# 2020-05-02
# 06:18:40 logout webserver.local
#
# 13:22:44 logout webserver.local
#
# 15:46:33 login webserver.local
#
# 2020-05-03
# 19:51:06 login mailserver.local
#
# 16:02:14 login webserver.local
#
# 11:35:05 login myworkstation.local
#
# 01:56:50 login mailserver.local
#
# 19:45:57 login webserver.local
#
# 2020-05-04
# 10:36:13 logout myworkstation.local
#
# 15:19:30 logout webserver.local
#
# 15:34:46 logout myworkstation.local
#
# 08:24:24 logout myworkstation.local
#
# 07:42:50 login mailserver.local
#
# 11:48:51 login webserver.local
#
# 2020-05-05
# 06:49:09 logout mailserver.local
#
# 08:43:09 logout webserver.local
#
# 2020-05-06
# 02:24:21 login mailserver.local
#
# 05:35:54 login mailserver.local
#
# 2020-05-07
# 09:54:06 logout mailserver.local
#
# 23:17:28 login webserver.local
#
# 02:26:44 login myworkstation.local
#
# 2020-05-08
# 09:28:53 logout mailserver.local
#
# 14:38:15 logout myworkstation.local
#
# 00:56:25 login webserver.local
#
# 2020-05-09
# 21:09:44 logout webserver.local
#
# 06:12:55 login mailserver.local
#
# 07:04:54 logout mailserver.local
#
# 23:32:28 logout webserver.local
#
# 21:34:56 logout webserver.local
#
# 01:57:24 login myworkstation.local
#
# 2020-05-10
# 06:37:48 login webserver.local
#
# 13:11:56 logout mailserver.local
#
# 10:33:17 logout myworkstation.local
#
# 2020-05-11
# 03:44:32 login webserver.local
#
# 11:54:58 logout webserver.local
#
# 08:34:19 logout myworkstation.local
#
# 13:14:11 login mailserver.local
#
# 20:37:41 logout myworkstation.local
#
# 16:23:33 logout myworkstation.local
#
# 2020-05-12
# 01:19:26 logout webserver.local
#
# 12:51:16 logout myworkstation.local
#
# 11:32:57 login webserver.local
#
# 12:01:50 logout myworkstation.local
#
# 2020-05-13
# 21:47:12 logout mailserver.local
#
# 01:54:50 login mailserver.local
#
# 02:18:19 logout myworkstation.local
#
# 05:36:03 login webserver.local
#
# 2020-05-14
# 22:56:47 login mailserver.local
#
# 03:53:44 login webserver.local
#
# 12:04:19 logout mailserver.local
#
# 2020-05-15
# 2020-05-16
# 11:43:30 logout myworkstation.local
#
# 20:18:11 login mailserver.local
#
# 14:34:59 logout myworkstation.local
#
# 2020-05-17
# 22:48:59 login myworkstation.local
#
# 09:56:29 logout webserver.local
#
# 00:41:24 logout myworkstation.local
#
# 2020-05-18
# 09:49:33 logout myworkstation.local
#
# 20:31:00 logout webserver.local
#
# 18:20:29 logout mailserver.local
#
# 2020-05-19
# 05:12:00 login mailserver.local
#
# 23:31:00 logout mailserver.local
#
# 23:48:24 login myworkstation.local
#
# 13:16:52 login myworkstation.local
#
# 08:19:10 logout myworkstation.local
#
# 00:57:32 logout webserver.local
#
# 2020-05-20
# 12:05:13 login webserver.local
#
# 04:15:46 login webserver.local
#
# 14:38:31 login myworkstation.local
#
# 13:35:47 logout myworkstation.local
#
# 21:33:40 login myworkstation.local
#
# 14:36:11 logout mailserver.local
#
# 20:57:10 logout myworkstation.local
#
# 2020-05-21
# 02:44:08 logout webserver.local
#
# 09:04:03 logout mailserver.local
#
# 04:40:04 logout mailserver.local
#
# 22:12:07 logout mailserver.local
#
# 2020-05-22
# 09:02:20 login webserver.local
#
# 00:47:50 login myworkstation.local
#
# 07:41:52 logout webserver.local
#
# 2020-05-23
# 13:23:03 logout webserver.local
#
# 17:34:52 logout mailserver.local
#
# 03:50:19 logout mailserver.local
#
# 2020-05-24
# 12:53:17 logout mailserver.local
#
# 19:17:04 logout mailserver.local
#
# 20:50:06 logout webserver.local
#
# 2020-05-25
# 02:31:59 logout mailserver.local
#
# 21:26:43 logout myworkstation.local
#
# 03:33:44 login myworkstation.local
#
# 18:55:03 login webserver.local
#
# 2020-05-26
# 21:07:38 login mailserver.local
#
# 07:05:14 login webserver.local
#
# 13:30:37 logout mailserver.local
#
# 2020-05-27
# 17:11:11 login webserver.local
#
# 23:38:54 login mailserver.local
#
# 13:41:12 login myworkstation.local
#
# 21:49:40 login mailserver.local
#
# 12:37:55 logout myworkstation.local
#
# 2020-05-28
# 04:03:04 logout myworkstation.local
#
# 08:41:32 logout mailserver.local
#
# 09:24:06 logout mailserver.local
#
# 14:50:50 login myworkstation.local
#
# 02:20:02 logout mailserver.local
#
# 2020-05-29
# 11:08:02 logout myworkstation.local
#
# 00:14:34 logout webserver.local
#
# 20:32:43 login webserver.local
#
# 19:49:25 logout myworkstation.local
#
# 2020-05-30
# 01:27:27 login myworkstation.local
#
# 09:39:12 login webserver.local
